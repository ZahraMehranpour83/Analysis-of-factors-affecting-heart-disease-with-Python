# %% [markdown]
# # Hart disease

# %% [markdown]
# ## Features

# %% [markdown]
# ### Feature1(age)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
database=fetch_openml(data_id= 43672)
df=pd.DataFrame(database.data,columns=database.feature_names)
age=np.array(df['age'])

Mage=np.mean(age)
min_age=np.min(age)
max_age=np.max(age)
print("mean age:",Mage,"min age:",min_age,"max age:",max_age)
##plot
fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].boxplot(age)
axs[0].set_ylabel('age')
axs[1].violinplot(age)
axs[1].set_ylabel('age')
axs[2].hist(age,color='black')
axs[2].set_xlabel('age')
axs[2].set_ylabel('number')
plt.tight_layout()
plt.show()
# Out:
# mean age: 53.72016806722689 min age: 28.0 max age: 77.0

# %% [markdown]
# ### Feature2(sex)

# %%
sex=np.array(df['sex'])
men_number=(df['sex']== 1).sum()
women_number=(df['sex']==0).sum()
Total=men_number+women_number
##compared
mCOMPAREDt=men_number/Total
wCOMPAREDt=women_number/Total
mCOMPAREDw=men_number/women_number
print('women:',women_number,'men:',men_number)
labels='men','women'
sizes=[mCOMPAREDt,wCOMPAREDt]
fig,ax=plt.subplots()
explode=(0,0.1)
ax.pie(sizes,explode=explode,labels=labels)
plt.show()
# Out:
# women: 281 men: 909

# %% [markdown]
# ###  Feature3(chest_pain_type)

# %%
chest_pain_type=np.array(df['chest_pain_type'])
Typicl_Angina=(df['chest_pain_type']== 1).sum()
T_COMPARED_T=Typicl_Angina/1190
Atypical_Angina=(df['chest_pain_type']==2).sum()
A_COMPARED_T=Atypical_Angina/1190
Non_anginalPain=(df['chest_pain_type']==3).sum()
N_COMPARED_T=Non_anginalPain/1190
Asymptomatic=(df['chest_pain_type']==4).sum()
AS_COMPARED_T=Asymptomatic/1190
print('Typicl_Angina:',Typicl_Angina,'Atypical_Angina:',Atypical_Angina,
      'Non_anginalPain:',Non_anginalPain,'Asymptomatic:',Asymptomatic)
labels='Typicl_Angina','Atypical_Angina','Non_anginalPain','Asymptomatic'
sizes=[T_COMPARED_T,AS_COMPARED_T,N_COMPARED_T,AS_COMPARED_T]
fig,ax=plt.subplots()
explode=(0,0,0,0)
ax.pie(sizes,explode=explode,labels=labels)
plt.show()
# Out:
# Typicl_Angina: 66 Atypical_Angina: 216 Non_anginalPain: 283 Asymptomatic: 625

# %% [markdown]
# ### Feature4(resting_bp_s)

# %%
resting_bp_s=np.array(df['resting_bp_s'])
M_rest=np.mean(resting_bp_s)
min_rest=np.min(resting_bp_s)
max_rest=np.max(resting_bp_s)
print('mean:',M_rest,'max:',max_rest,'min:',min_rest)
#######plot
fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].boxplot(resting_bp_s)
axs[0].set_ylabel('resting_b_s')
axs[1].violinplot(resting_bp_s)
axs[1].set_ylabel('resting_b_s')
axs[2].hist(resting_bp_s,color='black')
axs[2].set_xlabel('resting_bp_s')
axs[2].set_ylabel('number')
plt.tight_layout()
plt.show()
# Out:
# mean: 132.15378151260504 max: 200.0 min: 0.0

# %% [markdown]
# ### Feature5(cholesterol)

# %%
cholesterol = np.array(df['cholesterol'])
M_cholesterol = np.mean(cholesterol)
min_cholesterol = np.min(cholesterol)
max_cholesterol = np.max(cholesterol)
print('mean:',M_cholesterol, 'max:',max_cholesterol,'min:', min_cholesterol)
##plot
fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].boxplot(cholesterol)
axs[0].set_ylabel('cholesterol')
axs[1].violinplot(cholesterol)
axs[1].set_ylabel('cholesterol')
axs[2].hist(cholesterol, color='black')
axs[2].set_xlabel('cholesterol')
axs[2].set_ylabel('number')
plt.show()
# Out:
# mean: 210.36386554621848 max: 603.0 min: 0.0

# %% [markdown]
# ### Feature6(fasting_blood_sugar)

# %%
fasting_blood_sugar=np.array(df['fasting_blood_sugar'])
more_120=(df['fasting_blood_sugar']== 1).sum()
lees_120=(df['fasting_blood_sugar']==0).sum()
Total=more_120+lees_120
mCOMPAREDt=more_120/Total
lCOMPAREDt=lees_120/Total
mCOMPAREDl=more_120/lees_120
print('more_120:',more_120,'less_120:',lees_120)
labels='more_120','lees_120'
sizes=[mCOMPAREDt,lCOMPAREDt]
fig,ax=plt.subplots()
explode=(0,0.1)
ax.pie(sizes,explode=explode,labels=labels)
plt.show()
# Out:
# more_120: 254 less_120: 936

# %% [markdown]
# ### Feature7(resting_ecg)

# %%
resting_ecg=np.array(df['resting_ecg'])
Normal=(df['resting_ecg']== 0).sum()
ST_T=(df['resting_ecg']==1).sum()
left_ventricular_hypertrophy=(df['resting_ecg']==2).sum()
Total=Normal+ST_T+left_ventricular_hypertrophy
N_COMPARED_T=Normal/Total
S_COMPARED_T=ST_T/Total
L_COMPARED_T=left_ventricular_hypertrophy/Total
print('Normal:',Normal,'ST_T:',ST_T,'left_ventricular_hypertrophy:',left_ventricular_hypertrophy)
labels=['Normal','st_t','left_ventricular_hypertrophy']
sizes=[N_COMPARED_T,S_COMPARED_T,L_COMPARED_T]
fig,ax=plt.subplots()
explode=(0.1,0,0)
ax.pie(sizes,explode=explode,labels=labels)
plt.show()
# Out:
# Normal: 684 ST_T: 181 left_ventricular_hypertrophy: 325

# %% [markdown]
# ### Feature8(max_heart_rate)

# %%
max_heart_rate = np.array(df['max_heart_rate'])
M_rate= np.mean(max_heart_rate)
min_rate = np.min(max_heart_rate)
max_rate = np.max(max_heart_rate)
print('mean:',M_rate,'max:',max_rate,'min:',min_rate)
#####plot
fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].boxplot(max_heart_rate)
axs[0].set_ylabel('max_heart_rate')
axs[1].violinplot(max_heart_rate)
axs[1].set_ylabel('max_heart_rate')
axs[2].hist(max_heart_rate, color='black')
axs[2].set_xlabel('max_heart_rate')
axs[2].set_ylabel('number')
plt.tight_layout()
plt.show()
# Out:
# mean: 139.7327731092437 max: 202.0 min: 60.0

# %% [markdown]
# ### Feature9(exercise_angina)

# %%
exercise_angina=np.array(df['exercise_angina'])
no=(df['exercise_angina']== 0).sum()
yes=(df['exercise_angina']==1).sum()
nCOMPAREDt=no/1190
yCOMPAREDt=yes/1190
nCOMPAREDy=no/yes
print('no_pain:',no,'yes_pain:',yes)
labels='no_pain','yes_pain'
sizes=[nCOMPAREDt,yCOMPAREDt]
fig,ax=plt.subplots()
explode=(0,0.1)
ax.pie(sizes,explode=explode,labels=labels)
plt.show()
# Out:
# no_pain: 729 yes_pain: 461

# %% [markdown]
# ### Feature10(oldpeak)

# %%
oldpeak = np.array(df['oldpeak'])
M_oldpeak= np.mean(oldpeak)
min_oldpeak = np.min(oldpeak)
max_oldpeak = np.max(oldpeak)
print('mean:',M_oldpeak,'min:',min_oldpeak,'max:',max_oldpeak)
###plot
fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].boxplot(oldpeak)
axs[1].violinplot(oldpeak)
axs[2].hist(oldpeak, color='black')
axs[2].set_xlabel('oldpeak')
axs[2].set_ylabel('number')
plt.tight_layout()
plt.show()
# Out:
# mean: 0.9227731092436974 min: -2.6 max: 6.2

# %% [markdown]
# ### Feature11(ST_slope)

# %%
ST_slope=np.array(df['ST_slope'])#
upsloping=(df['ST_slope']== 1).sum()
flat=(df['ST_slope']==2).sum()
downsloping=(df['ST_slope']==3).sum()
U_COMPARED_t=upsloping/1190
F_COMPARED_t=flat/1190
D_COMPARED_T=downsloping/1190
print('upsloping:',upsloping,'flat;',flat,'downsloping:',downsloping)
labels='Upsloping','Flat','Downsloping'
sizes=[U_COMPARED_t,F_COMPARED_t,D_COMPARED_T]
fig,ax=plt.subplots()
explode=(0,0.1,0)
ax.pie(sizes,explode=explode,labels=labels)
plt.show()
# Out:
# upsloping: 526 flat; 582 downsloping: 81
